# %% [markdown]
# <a href="https://colab.research.google.com/github/leobertolazzi/aes-bert/blob/main/aes_s-bert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Automated Essay Scoring with Sentence-Transformers embeddings

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip install --quiet sentence_transformers
# Out:
#      |████████████████████████████████| 85 kB 946 kB/s
#      |████████████████████████████████| 5.8 MB 25.8 MB/s
#      |████████████████████████████████| 1.3 MB 67.8 MB/s
#      |████████████████████████████████| 182 kB 76.2 MB/s
#      |████████████████████████████████| 7.6 MB 60.4 MB/s
#   Building wheel for sentence-transformers (setup.py) ... done

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.metrics import cohen_kappa_score as kappa
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from sentence_transformers import SentenceTransformer
from matplotlib import pyplot as plt
from tqdm.auto import tqdm

# %%
# set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## Dataset

# %%
# Original kaggle training set
kaggle_dataset  = pd.read_csv('...', sep='\t', encoding = "ISO-8859-1")

# Smaller training set used for this project
dataset = pd.DataFrame(
  {
    'essay_id' : kaggle_dataset['essay_id'],
    'essay_set' : kaggle_dataset['essay_set'],
    'essay' : kaggle_dataset['essay'],
    'rater1' : kaggle_dataset['rater1_domain1'],
    'rater2' : kaggle_dataset['rater2_domain1'],
    'score' : kaggle_dataset['domain1_score']
  }
)

# %%
kaggle_dataset.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         1          1  Dear local newspaper, I think effects computer...
# 1         2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2         3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3         4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4         5          1  Dear @LOCATION1, I know having computers has a...
#
#    rater1_domain1  rater2_domain1  rater3_domain1  domain1_score  \
# 0               4               4             NaN              8
# 1               5               4             NaN              9
# 2               4               3             NaN              7
# 3               5               5             NaN             10
# 4               4               4             NaN              8
#
#    rater1_domain2  rater2_domain2  domain2_score  ...  rater2_trait3  \
# 0             NaN             NaN            NaN  ...            NaN
# 1             NaN             NaN            NaN  ...            NaN
# 2             NaN             NaN            NaN  ...            NaN
# 3             NaN             NaN            NaN  ...            NaN
# 4             NaN             NaN            NaN  ...            NaN
#
#    rater2_trait4  rater2_trait5  rater2_trait6  rater3_trait1  rater3_trait2  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    rater3_trait3  rater3_trait4  rater3_trait5  rater3_trait6
# 0            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN
#
# [5 rows x 28 columns]

# %%
dataset.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         1          1  Dear local newspaper, I think effects computer...
# 1         2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2         3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3         4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4         5          1  Dear @LOCATION1, I know having computers has a...
#
#    rater1  rater2  score
# 0       4       4      8
# 1       5       4      9
# 2       4       3      7
# 3       5       5     10
# 4       4       4      8

# %%
dataset.shape
# Out:
# (12976, 6)

# %% [markdown]
# ## Add Scaled Scores to Dataset

# %%
# Rescale target_score
scaler = StandardScaler()
scaled = []
for essay_set in range(1,9):
  score = dataset[dataset['essay_set'] == essay_set]['score'].to_frame()
  s = (scaler.fit_transform(score).reshape(-1))
  scaled = np.append(scaled, s)
    
dataset['scaled_score'] = scaled

# %%
dataset.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         1          1  Dear local newspaper, I think effects computer...
# 1         2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2         3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3         4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4         5          1  Dear @LOCATION1, I know having computers has a...
#
#    rater1  rater2  score  scaled_score
# 0       4       4      8     -0.343483
# 1       5       4      9      0.306655
# 2       4       3      7     -0.993622
# 3       5       5     10      0.956794
# 4       4       4      8     -0.343483

# %%
y = dataset['scaled_score'].to_frame()

# %%
plt.rcParams["figure.figsize"] = [8.50, 5.50]
y.hist(bins=60)
plt.title('Scaled scores')
plt.xlabel('score')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ## Essays Encoding

# %% [markdown]
# Essay are encoded following these steps:
# 1. the first 512 tokens of an essay are encoded in 768-d Sentence-Transformers embeddings;
# 2. the embedding of an essay is the average embedding of all tokens embeddings

# %%
sbert = SentenceTransformer('all-distilroberta-v1')
# Out:
# Downloading:   0%|          | 0.00/737 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/653 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/15.7k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/329M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/333 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
def get_id2emb(ids):

  id2emb = {}
  for n,id in enumerate(ids.to_list()):
    id2emb[id] = n
  
  return id2emb

# %%
print('Encoding essay embeddings')
essay_embeddings = sbert.encode(dataset['essay'].to_list(), convert_to_numpy=True, show_progress_bar=True, )
id2emb = get_id2emb(dataset['essay_id'])
print('Essay ids to emebeddings dictionary created.')
# Out:
# Encoding essay embeddings
# Batches:   0%|          | 0/406 [00:00<?, ?it/s]
# Essay ids to emebeddings dictionary created.

# %% [markdown]
# ## Dataloaders

# %%
def get_loader(df, id2emb, essay_embeddings, shuffle=True):

  # get embeddings from essay_id using id2emb dict
  embeddings = np.array([essay_embeddings[id2emb[id]] for id in df['essay_id']])

  # dataset and dataloader
  data = TensorDataset(torch.from_numpy(embeddings).float(), torch.from_numpy(np.array(df['scaled_score'])).float())
  loader = DataLoader(data, batch_size=128, shuffle=shuffle, num_workers=2)

  return loader

# %% [markdown]
# ## MLP Regressor

# %%
class MLPregressor(nn.Module):
  
  def __init__(self, input_size, hidden_size, output_size):
    super(MLPregressor, self).__init__()
    
    self.layers = nn.Sequential(
      nn.Linear(input_size, hidden_size),
      nn.Dropout(0.4),
      nn.ReLU(),
      nn.Linear(hidden_size, output_size)        
    )

  def forward(self, x):
    return self.layers(x)

# %%
def training_step(model, cost_function, optimizer, train_loader):

  samples = 0.
  cumulative_loss = 0.

  model.train() 

  for step, (inputs, targets) in enumerate(train_loader):

    inputs = inputs.squeeze(dim=1).to(device)
    targets = targets.reshape(targets.shape[0],1).to(device)

    outputs = model(inputs)

    loss = cost_function(outputs, targets)

    loss.backward()  
  
    optimizer.step()  
 
    optimizer.zero_grad()

    samples += inputs.shape[0]
    cumulative_loss += loss.item()

  return cumulative_loss/samples


def test_step(model, cost_function, optimizer, test_loader):

  samples = 0.
  cumulative_loss = 0.
  preds = []

  model.eval() 

  with torch.no_grad():
    for step, (inputs, targets) in enumerate(test_loader):

      inputs = inputs.squeeze(dim=1).to(device)
      targets = targets.reshape(targets.shape[0],1).to(device)

      outputs = model(inputs)

      loss = cost_function(outputs, targets)

      samples += inputs.shape[0]
      cumulative_loss += loss.item()
      for out in outputs:
        preds.append(float(out))

  return cumulative_loss/samples, preds

# %% [markdown]
# ## Training

# %%
# hyper-parameters
input_size = 768
hidden_size = 200
output_size = 1 
epochs = 20
lr = 3e-4

# cross-validation folds
kf = KFold(n_splits=5, random_state=2022, shuffle=True)

# dicts with test_df and predictions for each model
test_df_dict = {}
preds_dict = {}

for n, (train, test) in enumerate(kf.split(dataset)):
  
  # train, validation, test split
  train_df = dataset.iloc[train]
  test_df = dataset.iloc[test]
  # dataloaders
  train_loader = get_loader(train_df, id2emb, essay_embeddings, shuffle=True)
  test_loader = get_loader(test_df, id2emb, essay_embeddings, shuffle=False)

  # model
  print('------------------------------------------------------------------')
  print(f"\t\t\tTraining model: {n+1}")
  print('------------------------------------------------------------------')
  model = MLPregressor(input_size, hidden_size, output_size).to(device)
  
  # loss and optimizer
  cost_function = nn.MSELoss()
  optimizer = torch.optim.Adam(model.parameters(), lr=lr)

  # training
  train_loss, train_preds = test_step(model, cost_function, optimizer, train_loader)
  test_loss, test_preds = test_step(model, cost_function, optimizer, test_loader)
  print('Before training:\tLoss/train: {:.5f}\tLoss/test: {:.5f}'.format(train_loss, test_loss))

  for epoch in range(epochs):
    train_loss = training_step(model, cost_function, optimizer, train_loader)
    test_loss, test_preds = test_step(model, cost_function, optimizer, test_loader)
    print('Epoch: {:}\t\tLoss/train: {:.5f}\tLoss/test: {:.5f}'.format(epoch+1,train_loss, test_loss))

  train_loss, train_preds = test_step(model, cost_function, optimizer, train_loader)
  test_loss, test_preds = test_step(model, cost_function, optimizer, test_loader)
  print('After training:\t\tLoss/train: {:.5f}\tLoss/test: {:.5f}'.format(train_loss, test_loss))

  # store test_df and predictions
  test_df_dict[f"model_{n+1}"] = test_df
  preds_dict[f"model_{n+1}"] = test_preds
# Out:
# ------------------------------------------------------------------
# 			Training model: 1
# ------------------------------------------------------------------
# Before training:	Loss/train: 0.00784	Loss/test: 0.00845
# Epoch: 1		Loss/train: 0.00730	Loss/test: 0.00708
# Epoch: 2		Loss/train: 0.00576	Loss/test: 0.00555
# Epoch: 3		Loss/train: 0.00475	Loss/test: 0.00483
# Epoch: 4		Loss/train: 0.00424	Loss/test: 0.00450
# Epoch: 5		Loss/train: 0.00400	Loss/test: 0.00436
# Epoch: 6		Loss/train: 0.00385	Loss/test: 0.00420
# Epoch: 7		Loss/train: 0.00372	Loss/test: 0.00412
# Epoch: 8		Loss/train: 0.00362	Loss/test: 0.00405
# Epoch: 9		Loss/train: 0.00355	Loss/test: 0.00400
# Epoch: 10		Loss/train: 0.00353	Loss/test: 0.00392
# Epoch: 11		Loss/train: 0.00344	Loss/test: 0.00388
# Epoch: 12		Loss/train: 0.00338	Loss/test: 0.00384
# Epoch: 13		Loss/train: 0.00338	Loss/test: 0.00378
# Epoch: 14		Loss/train: 0.00330	Loss/test: 0.00375
# Epoch: 15		Loss/train: 0.00329	Loss/test: 0.00375
# Epoch: 16		Loss/train: 0.00321	Loss/test: 0.00369
# Epoch: 17		Loss/train: 0.00321	Loss/test: 0.00366
# Epoch: 18		Loss/train: 0.00317	Loss/test: 0.00365
# Epoch: 19		Loss/train: 0.00314	Loss/test: 0.00361
# Epoch: 20		Loss/train: 0.00309	Loss/test: 0.00359
# After training:		Loss/train: 0.00297	Loss/test: 0.00359
# ------------------------------------------------------------------
# 			Training model: 2
# ------------------------------------------------------------------
# Before training:	Loss/train: 0.00786	Loss/test: 0.00820
# Epoch: 1		Loss/train: 0.00739	Loss/test: 0.00692
# Epoch: 2		Loss/train: 0.00587	Loss/test: 0.00545
# Epoch: 3		Loss/train: 0.00478	Loss/test: 0.00475
# Epoch: 4		Loss/train: 0.00428	Loss/test: 0.00440
# Epoch: 5		Loss/train: 0.00408	Loss/test: 0.00421
# Epoch: 6		Loss/train: 0.00388	Loss/test: 0.00415
# Epoch: 7		Loss/train: 0.00376	Loss/test: 0.00400
# Epoch: 8		Loss/train: 0.00365	Loss/test: 0.00393
# Epoch: 9		Loss/train: 0.00357	Loss/test: 0.00387
# Epoch: 10		Loss/train: 0.00351	Loss/test: 0.00383
# Epoch: 11		Loss/train: 0.00346	Loss/test: 0.00378
# Epoch: 12		Loss/train: 0.00338	Loss/test: 0.00372
# Epoch: 13		Loss/train: 0.00336	Loss/test: 0.00369
# Epoch: 14		Loss/train: 0.00330	Loss/test: 0.00365
# Epoch: 15		Loss/train: 0.00328	Loss/test: 0.00363
# Epoch: 16		Loss/train: 0.00322	Loss/test: 0.00361
# Epoch: 17		Loss/train: 0.00319	Loss/test: 0.00357
# Epoch: 18		Loss/train: 0.00317	Loss/test: 0.00355
# Epoch: 19		Loss/train: 0.00314	Loss/test: 0.00353
# Epoch: 20		Loss/train: 0.00312	Loss/test: 0.00350
# After training:		Loss/train: 0.00297	Loss/test: 0.00350
# ------------------------------------------------------------------
# 			Training model: 3
# ------------------------------------------------------------------
# Before training:	Loss/train: 0.00780	Loss/test: 0.00836
# Epoch: 1		Loss/train: 0.00725	Loss/test: 0.00695
# Epoch: 2		Loss/train: 0.00573	Loss/test: 0.00543
# Epoch: 3		Loss/train: 0.00471	Loss/test: 0.00473
# Epoch: 4		Loss/train: 0.00426	Loss/test: 0.00443
# Epoch: 5		Loss/train: 0.00401	Loss/test: 0.00420
# Epoch: 6		Loss/train: 0.00379	Loss/test: 0.00409
# Epoch: 7		Loss/train: 0.00368	Loss/test: 0.00403
# Epoch: 8		Loss/train: 0.00359	Loss/test: 0.00397
# Epoch: 9		Loss/train: 0.00351	Loss/test: 0.00388
# Epoch: 10		Loss/train: 0.00347	Loss/test: 0.00384
# Epoch: 11		Loss/train: 0.00343	Loss/test: 0.00383
# Epoch: 12		Loss/train: 0.00337	Loss/test: 0.00378
# Epoch: 13		Loss/train: 0.00331	Loss/test: 0.00376
# Epoch: 14		Loss/train: 0.00326	Loss/test: 0.00369
# Epoch: 15		Loss/train: 0.00325	Loss/test: 0.00371
# Epoch: 16		Loss/train: 0.00318	Loss/test: 0.00365
# Epoch: 17		Loss/train: 0.00315	Loss/test: 0.00364
# Epoch: 18		Loss/train: 0.00311	Loss/test: 0.00362
# Epoch: 19		Loss/train: 0.00309	Loss/test: 0.00361
# Epoch: 20		Loss/train: 0.00307	Loss/test: 0.00359
# After training:		Loss/train: 0.00294	Loss/test: 0.00359
# ------------------------------------------------------------------
# 			Training model: 4
# ------------------------------------------------------------------
# Before training:	Loss/train: 0.00798	Loss/test: 0.00795
# Epoch: 1		Loss/train: 0.00739	Loss/test: 0.00674
# Epoch: 2		Loss/train: 0.00585	Loss/test: 0.00537
# Epoch: 3		Loss/train: 0.00477	Loss/test: 0.00464
# Epoch: 4		Loss/train: 0.00435	Loss/test: 0.00428
# Epoch: 5		Loss/train: 0.00405	Loss/test: 0.00409
# Epoch: 6		Loss/train: 0.00390	Loss/test: 0.00394
# Epoch: 7		Loss/train: 0.00379	Loss/test: 0.00386
# Epoch: 8		Loss/train: 0.00370	Loss/test: 0.00381
# Epoch: 9		Loss/train: 0.00360	Loss/test: 0.00372
# Epoch: 10		Loss/train: 0.00351	Loss/test: 0.00365
# Epoch: 11		Loss/train: 0.00354	Loss/test: 0.00361
# Epoch: 12		Loss/train: 0.00344	Loss/test: 0.00359
# Epoch: 13		Loss/train: 0.00340	Loss/test: 0.00357
# Epoch: 14		Loss/train: 0.00335	Loss/test: 0.00357
# Epoch: 15		Loss/train: 0.00334	Loss/test: 0.00351
# Epoch: 16		Loss/train: 0.00326	Loss/test: 0.00350
# Epoch: 17		Loss/train: 0.00323	Loss/test: 0.00347
# Epoch: 18		Loss/train: 0.00318	Loss/test: 0.00345
# Epoch: 19		Loss/train: 0.00316	Loss/test: 0.00343
# Epoch: 20		Loss/train: 0.00314	Loss/test: 0.00341
# After training:		Loss/train: 0.00298	Loss/test: 0.00341
# ------------------------------------------------------------------
# 			Training model: 5
# ------------------------------------------------------------------
# Before training:	Loss/train: 0.00802	Loss/test: 0.00777
# Epoch: 1		Loss/train: 0.00741	Loss/test: 0.00645
# Epoch: 2		Loss/train: 0.00585	Loss/test: 0.00505
# Epoch: 3		Loss/train: 0.00481	Loss/test: 0.00442
# Epoch: 4		Loss/train: 0.00438	Loss/test: 0.00411
# Epoch: 5		Loss/train: 0.00413	Loss/test: 0.00391
# Epoch: 6		Loss/train: 0.00397	Loss/test: 0.00380
# Epoch: 7		Loss/train: 0.00383	Loss/test: 0.00369
# Epoch: 8		Loss/train: 0.00376	Loss/test: 0.00362
# Epoch: 9		Loss/train: 0.00365	Loss/test: 0.00355
# Epoch: 10		Loss/train: 0.00358	Loss/test: 0.00351
# Epoch: 11		Loss/train: 0.00353	Loss/test: 0.00346
# Epoch: 12		Loss/train: 0.00348	Loss/test: 0.00342
# Epoch: 13		Loss/train: 0.00344	Loss/test: 0.00340
# Epoch: 14		Loss/train: 0.00341	Loss/test: 0.00339
# Epoch: 15		Loss/train: 0.00335	Loss/test: 0.00336
# Epoch: 16		Loss/train: 0.00330	Loss/test: 0.00333
# Epoch: 17		Loss/train: 0.00325	Loss/test: 0.00330
# Epoch: 18		Loss/train: 0.00321	Loss/test: 0.00329
# Epoch: 19		Loss/train: 0.00320	Loss/test: 0.00329
# Epoch: 20		Loss/train: 0.00317	Loss/test: 0.00326
# After training:		Loss/train: 0.00304	Loss/test: 0.00326

# %% [markdown]
# ## Overall Results

# %%
def get_results_df(test_df, model_preds):

  # create new results df with model scaled preds
  preds_df = pd.DataFrame(model_preds)
  results_df = test_df.reset_index(drop=True)\
              .join(preds_df)\
              .rename(columns={0:'scaled_pred'})\
              .sort_values(by='essay_set')\
              .reset_index(drop=True)

  # move score to last colum
  s_df = results_df.pop('score')
  results_df['score'] = s_df

  # scale back to original range by essay set
  preds = pd.Series(dtype='float64')
  for essay_set in range(1,9):
    scaler = StandardScaler()  
    score_df = test_df[test_df['essay_set'] == essay_set]['score'].to_frame()
    scaler.fit(score_df)
    scaled_preds = results_df.loc[results_df['essay_set'] == essay_set, 'scaled_pred'].to_frame()
    preds_rescaled = scaler.inverse_transform(scaled_preds).round(0).astype('int')
    preds = preds.append(pd.Series(np.squeeze(np.asarray(preds_rescaled))), ignore_index=True)

  # append to results df
  results_df['pred'] = preds

  return results_df

# %%
# list of mqw_kappa for each model
mqwk_list = []

for model_id in test_df_dict:

  # test_df and preds for current model
  test_df = test_df_dict[model_id]
  model_preds = preds_dict[model_id]

  results_df = get_results_df(test_df, model_preds)

  kappas_by_set = []
  for essay_set in range(1,9):
    kappas_by_set.append(kappa(results_df.loc[results_df['essay_set'] == essay_set, 'score'],
                            results_df.loc[results_df['essay_set'] == essay_set, 'pred'],
                            weights='quadratic'))
    
  mqwk_list.append(np.mean(kappas_by_set))
print('----------------------------------------------')
print('mean QWK after 5-fold cross-validation:\t{:.4f}'.format(np.mean(mqwk_list)))
print('Max mean QWK:\t\t\t\t{:.4f}'.format(max(mqwk_list)))
print('Min mean QWK:\t\t\t\t{:.4f}'.format(min(mqwk_list)))

raters_kappas = []
for essay_set in range(1,9):
  raters_kappas.append(kappa(dataset.loc[dataset['essay_set'] == essay_set, 'rater1'], 
                      dataset.loc[dataset['essay_set'] == essay_set, 'rater2'],
                      weights='quadratic'))
  
mqwk_raters = np.mean(raters_kappas)
print('----------------------------------------------')
print('mean QWK for two human raters:\t\t{:.4f}'.format(mqwk_raters))
print('----------------------------------------------')
# Out:
# ----------------------------------------------
# mean QWK after 5-fold cross-validation:	0.6837
# Max mean QWK:				0.6945
# Min mean QWK:				0.6750
# ----------------------------------------------
# mean QWK for two human raters:		0.7537
# ----------------------------------------------

# %% [markdown]
# ## Results by Model

# %%
def show_results(id):
  model_id = f"model_{id}"
  test_df = test_df_dict[model_id]
  model_preds = preds_dict[model_id]

  results_df = get_results_df(test_df, model_preds)

  kappas_by_set = []
  for essay_set in range(1,9):
    kappas_by_set.append(kappa(results_df.loc[results_df['essay_set'] == essay_set, 'score'],
                            results_df.loc[results_df['essay_set'] == essay_set, 'pred'],
                            weights='quadratic'))
  print('--------------------------------------')
  print(f"\tResults for model: {id}")
  print('--------------------------------------')
  for essay_set in range(8):
    print('Kappa for essay set {:}:\t\t{:.4f}'.format(essay_set+1, kappas_by_set[essay_set]))
  print('mean QWK:\t\t\t{:.4f}'.format(np.mean(kappas_by_set)))
  
  return results_df

def plot_results(results_df, id):
  set_number = 0
  fig, ax = plt.subplots(4,2, figsize=(9,9), sharey=False)
  for i in range(4):
    for j in range(2):
      set_number += 1
      results_df[results_df['essay_set'] == set_number]\
        [['score', 'pred']]\
        .plot.hist(histtype='step', bins=20, ax=ax[i, j], rot=0)
      ax[i,j].set_title('Set %i' % set_number)
  ax[3,0].locator_params(nbins=10)
  ax[3,1].locator_params(nbins=10)
  plt.suptitle(f'Histograms of scores for Model {id}')
  plt.tight_layout(rect=[0, 0.03, 1, 0.95])
  plt.show()

# %% [markdown]
# ### Model 1

# %%
results_df = show_results(1)
# Out:
# --------------------------------------
# 	Results for model: 1
# --------------------------------------
# Kappa for essay set 1:		0.6925
# Kappa for essay set 2:		0.5947
# Kappa for essay set 3:		0.6058
# Kappa for essay set 4:		0.7147
# Kappa for essay set 5:		0.7295
# Kappa for essay set 6:		0.7983
# Kappa for essay set 7:		0.7743
# Kappa for essay set 8:		0.6461
# mean QWK:			0.6945

# %%
results_df.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 1      1267          1  In my opinion i think computers have a positiv...
# 2      1263          1  Dear @ORGANIZATION1, I think that more people ...
# 3      1260          1  Dear local newspaper, @CAPS1 name is @CAPS2 @C...
# 4      1259          1  To whomever this @MONTH1 concern, @CAPS1 your ...
#
#    rater1  rater2  scaled_score  scaled_pred  score  pred
# 0       4       3     -0.993622    -0.164447      7     8
# 1       4       4     -0.343483    -0.762306      8     7
# 2       5       4      0.306655    -0.570050      9     8
# 3       4       4     -0.343483    -0.067279      8     9
# 4       5       5      0.956794     0.951817     10    10

# %%
plot_results(results_df, 1)

# %% [markdown]
# ### Model 2

# %%
results_df = show_results(2)
# Out:
# --------------------------------------
# 	Results for model: 2
# --------------------------------------
# Kappa for essay set 1:		0.7229
# Kappa for essay set 2:		0.6540
# Kappa for essay set 3:		0.6058
# Kappa for essay set 4:		0.7256
# Kappa for essay set 5:		0.7601
# Kappa for essay set 6:		0.7070
# Kappa for essay set 7:		0.7318
# Kappa for essay set 8:		0.6229
# mean QWK:			0.6913

# %%
results_df.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         5          1  Dear @LOCATION1, I know having computers has a...
# 1      1162          1  Dear Local @CAPS1 Newspaper, @CAPS2 I see why ...
# 2      1154          1  Dear Readers, I understand that some @MONTH1 t...
# 3      1148          1  Dear @CAPS1, @CAPS2 you probably have seen the...
# 4      1147          1  Dear @ORGANIZATION1 staff, Are computers helpf...
#
#    rater1  rater2  scaled_score  scaled_pred  score  pred
# 0       4       4     -0.343483    -0.011860      8     8
# 1       4       4     -0.343483     0.480851      8     9
# 2       4       4     -0.343483    -0.882252      8     7
# 3       5       4      0.306655     0.703608      9    10
# 4       4       5      0.306655     0.818405      9    10

# %%
plot_results(results_df, 2)

# %% [markdown]
# ### Model 3

# %%
results_df = show_results(3)
# Out:
# --------------------------------------
# 	Results for model: 3
# --------------------------------------
# Kappa for essay set 1:		0.7573
# Kappa for essay set 2:		0.6564
# Kappa for essay set 3:		0.6292
# Kappa for essay set 4:		0.7423
# Kappa for essay set 5:		0.7532
# Kappa for essay set 6:		0.7342
# Kappa for essay set 7:		0.7314
# Kappa for essay set 8:		0.4324
# mean QWK:			0.6796

# %%
results_df.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 1      1208          1  I disaree with computers are for you becau if ...
# 2      1204          1  To @CAPS1 @CAPS6 @MONTH1 concern: @CAPS2 I hav...
# 3      1200          1  Dear local newspaper, @CAPS1 it has been broug...
# 4      1199          1  Computers are helpful in everyone's life. New ...
#
#    rater1  rater2  scaled_score  scaled_pred  score  pred
# 0       5       4      0.306655     0.585644      9     9
# 1       3       4     -0.993622    -1.350542      7     6
# 2       4       5      0.306655     0.956887      9    10
# 3       5       4      0.306655     0.565961      9     9
# 4       4       4     -0.343483     0.267694      8     9

# %%
plot_results(results_df, 3)

# %% [markdown]
# ### Model 4

# %%
results_df = show_results(4)
# Out:
# --------------------------------------
# 	Results for model: 4
# --------------------------------------
# Kappa for essay set 1:		0.7207
# Kappa for essay set 2:		0.6204
# Kappa for essay set 3:		0.6333
# Kappa for essay set 4:		0.7397
# Kappa for essay set 5:		0.7554
# Kappa for essay set 6:		0.7222
# Kappa for essay set 7:		0.6711
# Kappa for essay set 8:		0.5374
# mean QWK:			0.6750

# %%
results_df.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         1          1  Dear local newspaper, I think effects computer...
# 1      1165          1  Dear @PERSON1 @CAPS1 I am writing this letter ...
# 2      1164          1  Dear @CAPS1, I am aware of the current debate ...
# 3      1163          1  Dear Newspaper, I strongly believe that the ef...
# 4      1158          1  Dear newspaper I think that there are many rea...
#
#    rater1  rater2  scaled_score  scaled_pred  score  pred
# 0       4       4     -0.343483     0.375585      8     9
# 1       4       4     -0.343483     0.200083      8     9
# 2       4       5      0.306655     0.458056      9     9
# 3       5       5      0.956794     1.159398     10    10
# 4       4       5      0.306655     0.233729      9     9

# %%
plot_results(results_df, 4)

# %% [markdown]
# ### Model 5

# %%
results_df = show_results(5)
# Out:
# --------------------------------------
# 	Results for model: 5
# --------------------------------------
# Kappa for essay set 1:		0.7004
# Kappa for essay set 2:		0.6881
# Kappa for essay set 3:		0.5816
# Kappa for essay set 4:		0.7273
# Kappa for essay set 5:		0.7609
# Kappa for essay set 6:		0.7108
# Kappa for essay set 7:		0.7554
# Kappa for essay set 8:		0.4989
# mean QWK:			0.6779

# %%
results_df.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         6          1  Dear @LOCATION1, I think that computers have a...
# 1      1268          1  People use computers everyday. There's so many...
# 2      1265          1  Dear editors, I was planning on taking a trip ...
# 3      1261          1  Have you ever had someone move away and you wa...
# 4      1250          1  Dear The @CAPS1 newspaper, @CAPS2 in front of ...
#
#    rater1  rater2  scaled_score  scaled_pred  score  pred
# 0       4       4     -0.343483    -0.405464      8     8
# 1       4       4     -0.343483    -0.258503      8     8
# 2       5       5      0.956794     0.252071     10     9
# 3       4       5      0.306655     0.187129      9     9
# 4       6       6      2.257071     0.981035     12    10

# %%
plot_results(results_df, 5)
