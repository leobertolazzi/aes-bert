# %% [markdown]
# <a href="https://colab.research.google.com/github/leobertolazzi/aes-bert/blob/main/aes_bert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Automated Essay Scoring with BERT embeddings

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.metrics import cohen_kappa_score as kappa
import torch
from torch.utils.data import DataLoader, TensorDataset
from transformers import BertTokenizer, BertModel
from matplotlib import pyplot as plt
from tqdm.auto import tqdm

# %% [markdown]
# ## Device

# %%
# set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## Dataset

# %%
# Original kaggle training set
kaggle_dataset  = pd.read_csv('data/training_set_rel3.tsv', sep='\t', encoding = "ISO-8859-1")

# Smaller training set used for this project
dataset = pd.DataFrame(
  {
    'essay_id' : kaggle_dataset['essay_id'],
    'essay_set' : kaggle_dataset['essay_set'],
    'essay' : kaggle_dataset['essay'],
    'rater1' : kaggle_dataset['rater1_domain1'],
    'rater2' : kaggle_dataset['rater2_domain1'],
    'score' : kaggle_dataset['domain1_score']
  }
)

# %%
kaggle_dataset.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         1          1  Dear local newspaper, I think effects computer...
# 1         2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2         3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3         4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4         5          1  Dear @LOCATION1, I know having computers has a...
#
#    rater1_domain1  rater2_domain1  rater3_domain1  domain1_score  \
# 0               4               4             NaN              8
# 1               5               4             NaN              9
# 2               4               3             NaN              7
# 3               5               5             NaN             10
# 4               4               4             NaN              8
#
#    rater1_domain2  rater2_domain2  domain2_score  ...  rater2_trait3  \
# 0             NaN             NaN            NaN  ...            NaN
# 1             NaN             NaN            NaN  ...            NaN
# 2             NaN             NaN            NaN  ...            NaN
# 3             NaN             NaN            NaN  ...            NaN
# 4             NaN             NaN            NaN  ...            NaN
#
#    rater2_trait4  rater2_trait5  rater2_trait6  rater3_trait1  rater3_trait2  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    rater3_trait3  rater3_trait4  rater3_trait5  rater3_trait6
# 0            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN
#
# [5 rows x 28 columns]

# %%
dataset.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         1          1  Dear local newspaper, I think effects computer...
# 1         2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2         3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3         4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4         5          1  Dear @LOCATION1, I know having computers has a...
#
#    rater1  rater2  score
# 0       4       4      8
# 1       5       4      9
# 2       4       3      7
# 3       5       5     10
# 4       4       4      8

# %%
dataset.shape
# Out:
# (12976, 6)

# %% [markdown]
# ## Average Essay Length

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-cased')
# Out:
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
length_dict = {}

for essay_set in range(1,9):
    length_dict[essay_set] = [len(tokenizer.tokenize(essay)) for essay in dataset[dataset['essay_set'] == essay_set]['essay']]

# %%
set_number = 0
fig, ax = plt.subplots(4,2, figsize=(9,9), sharey=False)
for i in range(4):
  for j in range(2):
      set_number += 1
      ax[i,j].hist(length_dict[set_number], bins=30)
      ax[i,j].axvline(512, c="red")
      ax[i,j].set_title('Set %i' % set_number)
ax[3,0].locator_params(nbins=10)
ax[3,1].locator_params(nbins=10)
plt.suptitle('Essay lenght in token by essay set')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# As it can be seen, most of the essays are less than 512 tokens.
#
# However, for set 1 and 2 more or less half of the essays are more than 512 tokens; for set 8 most essays are more the 512 tokens.
#
# For set 1, 2 and 8 part of the information will be lost due to the limitation of BERT to encode a sequence of 512 tokens.

# %% [markdown]
# ## Add Scaled Scores to Dataset

# %%
def get_scaled_dataset(dataset):

  scaler = StandardScaler()
  scaled = []
  for essay_set in range(1,9):
    score = dataset[dataset['essay_set'] == essay_set]['score'].to_frame()
    s = (scaler.fit_transform(score).reshape(-1))
    scaled = np.append(scaled, s)

  scaled_dataset = dataset.copy()
  scaled_dataset['scaled_score'] = scaled

  return scaled_dataset

# %% [markdown]
# ## Essays Encoding

# %% [markdown]
# ### Id to Embedding dictionary

# %% [markdown]
# `get_id2emb` creates a dictionary which maps essay ids to the embeddings encoded by the two models

# %%
def get_id2emb(ids):

  id2emb = {}
  for n,id in enumerate(ids.to_list()):
    id2emb[id] = n

  print('Essay ids to emebeddings dictionary created.')
  
  return id2emb

# %%
id2emb = get_id2emb(dataset['essay_id'])
# Out:
# Essay ids to emebeddings dictionary created.

# %% [markdown]
# ### BERT Encoding

# %% [markdown]
# Essay are encoded following these steps:
# 1. the first 512 tokens of an essay are encoded in 768-d BERT embeddings;
# 2. the embedding of an essay is the average embedding of all tokens embeddings

# %%
bert = BertModel.from_pretrained("bert-base-cased").to(device)
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def mean_encoding(essay_list, model, tokenizer):

  print('Encoding essay embeddings:')

  embeddings = []
  for essay in tqdm(essay_list):
    encoded_input = tokenizer(essay, padding=True, truncation=True, return_tensors='pt').to(device)
    with torch.no_grad():
      model_output = model(**encoded_input)
    tokens_embeddings = np.matrix(model_output[0].squeeze().cpu())
    embeddings.append(np.squeeze(np.asarray(tokens_embeddings.mean(0))))

  return np.matrix(embeddings)

# %%
essay_embeddings = mean_encoding(dataset['essay'], bert, tokenizer)
# Out:
# Encoding essay embeddings:
#   0%|          | 0/12976 [00:00<?, ?it/s]

# %% [markdown]
# ## Dataloaders

# %%
def get_loader(df, id2emb, essay_embeddings, shuffle=True):

  # get embeddings from essay_id using id2emb dict
  embeddings = np.array([essay_embeddings[id2emb[id]] for id in df['essay_id']])

  # dataset and dataloader
  data = TensorDataset(torch.from_numpy(embeddings).float(), torch.from_numpy(np.array(df['scaled_score'])).float())
  loader = DataLoader(data, batch_size=128, shuffle=shuffle, num_workers=2)

  return loader

# %% [markdown]
# ## MLP Regressor

# %%
class MLP(torch.nn.Module):
  
  def __init__(self, input_size):
    super(MLP, self).__init__()
    
    self.layers = torch.nn.Sequential(
      torch.nn.Linear(input_size, 256),
      torch.nn.ReLU(),
      torch.nn.Dropout(0.3),
      torch.nn.Linear(256, 96),
      torch.nn.ReLU(),
      torch.nn.Dropout(0.3),
      torch.nn.Linear(96, 1)
    ) 

  def forward(self, x):
    return self.layers(x)

# %%
def training_step(model, cost_function, optimizer, train_loader):

  samples = 0.
  cumulative_loss = 0.

  model.train() 

  for step, (inputs, targets) in enumerate(train_loader):

    inputs = inputs.squeeze(dim=1).to(device)
    targets = targets.reshape(targets.shape[0],1).to(device)

    outputs = model(inputs)

    loss = cost_function(outputs, targets)

    loss.backward()  
  
    optimizer.step()  
 
    optimizer.zero_grad()

    samples += inputs.shape[0]
    cumulative_loss += loss.item()

  return cumulative_loss/samples


def test_step(model, cost_function, optimizer, test_loader):

  samples = 0.
  cumulative_loss = 0.
  preds = []

  model.eval() 

  with torch.no_grad():
    for step, (inputs, targets) in enumerate(test_loader):

      inputs = inputs.squeeze(dim=1).to(device)
      targets = targets.reshape(targets.shape[0],1).to(device)

      outputs = model(inputs)

      loss = cost_function(outputs, targets)

      samples += inputs.shape[0]
      cumulative_loss += loss.item()
      for out in outputs:
        preds.append(float(out))

  return cumulative_loss/samples, preds

# %% [markdown]
# ## Training

# %%
# hyper-parameters
input_size = 768
epochs = 20
lr = 3e-4

# cross-validation folds
kf = KFold(n_splits=5, random_state=2022, shuffle=True)

# dicts with train_df, test_df and predictions for each model
train_df_dict = {}
test_df_dict = {}
preds_dict = {}

# copy of dataset with scaled scores computed using the whole dataset
scaled_dataset = get_scaled_dataset(dataset)

for n, (train, test) in enumerate(kf.split(dataset)):
  
  # train, test splits 
  # scaled scores in train_df are computed only using training data
  train_df = dataset.iloc[train]
  train_df = get_scaled_dataset(train_df)

  test_df = scaled_dataset.iloc[test]

  # dataloaders
  train_loader = get_loader(train_df, id2emb, essay_embeddings, shuffle=True)
  test_loader = get_loader(test_df, id2emb, essay_embeddings, shuffle=False)

  # model
  print('------------------------------------------------------------------')
  print(f"\t\t\tTraining model: {n+1}")
  print('------------------------------------------------------------------')
  model = MLP(input_size).to(device)
  
  # loss and optimizer
  cost_function = torch.nn.MSELoss()
  optimizer = torch.optim.Adam(model.parameters(), lr=lr)

  # training
  train_loss, train_preds = test_step(model, cost_function, optimizer, train_loader)
  test_loss, test_preds = test_step(model, cost_function, optimizer, test_loader)
  print('Before training:\tLoss/train: {:.5f}\tLoss/test: {:.5f}'.format(train_loss, test_loss))

  for epoch in range(epochs):
    train_loss = training_step(model, cost_function, optimizer, train_loader)
    test_loss, test_preds = test_step(model, cost_function, optimizer, test_loader)
    print('Epoch: {:}\t\tLoss/train: {:.5f}\tLoss/test: {:.5f}'.format(epoch+1,train_loss, test_loss))

  train_loss, train_preds = test_step(model, cost_function, optimizer, train_loader)
  test_loss, test_preds = test_step(model, cost_function, optimizer, test_loader)
  print('After training:\t\tLoss/train: {:.5f}\tLoss/test: {:.5f}'.format(train_loss, test_loss))

  # store train_df, test_df and predictions
  train_df_dict[f"model_{n+1}"] = train_df
  test_df_dict[f"model_{n+1}"] = test_df
  preds_dict[f"model_{n+1}"] = test_preds
# Out:
# ------------------------------------------------------------------
# 			Training model: 1
# ------------------------------------------------------------------
# Before training:	Loss/train: 0.00788	Loss/test: 0.00848
# Epoch: 1		Loss/train: 0.00594	Loss/test: 0.00535
# Epoch: 2		Loss/train: 0.00403	Loss/test: 0.00398
# Epoch: 3		Loss/train: 0.00358	Loss/test: 0.00372
# Epoch: 4		Loss/train: 0.00344	Loss/test: 0.00355
# Epoch: 5		Loss/train: 0.00334	Loss/test: 0.00347
# Epoch: 6		Loss/train: 0.00322	Loss/test: 0.00342
# Epoch: 7		Loss/train: 0.00317	Loss/test: 0.00335
# Epoch: 8		Loss/train: 0.00311	Loss/test: 0.00336
# Epoch: 9		Loss/train: 0.00307	Loss/test: 0.00335
# Epoch: 10		Loss/train: 0.00303	Loss/test: 0.00322
# Epoch: 11		Loss/train: 0.00296	Loss/test: 0.00323
# Epoch: 12		Loss/train: 0.00292	Loss/test: 0.00320
# Epoch: 13		Loss/train: 0.00290	Loss/test: 0.00319
# Epoch: 14		Loss/train: 0.00285	Loss/test: 0.00328
# Epoch: 15		Loss/train: 0.00281	Loss/test: 0.00333
# Epoch: 16		Loss/train: 0.00284	Loss/test: 0.00319
# Epoch: 17		Loss/train: 0.00273	Loss/test: 0.00311
# Epoch: 18		Loss/train: 0.00271	Loss/test: 0.00311
# Epoch: 19		Loss/train: 0.00269	Loss/test: 0.00313
# Epoch: 20		Loss/train: 0.00269	Loss/test: 0.00309
# After training:		Loss/train: 0.00240	Loss/test: 0.00309
# ------------------------------------------------------------------
# 			Training model: 2
# ------------------------------------------------------------------
# Before training:	Loss/train: 0.00793	Loss/test: 0.00822
# Epoch: 1		Loss/train: 0.00582	Loss/test: 0.00425
# Epoch: 2		Loss/train: 0.00402	Loss/test: 0.00380
# Epoch: 3		Loss/train: 0.00362	Loss/test: 0.00351
# Epoch: 4		Loss/train: 0.00338	Loss/test: 0.00330
# Epoch: 5		Loss/train: 0.00330	Loss/test: 0.00324
# Epoch: 6		Loss/train: 0.00318	Loss/test: 0.00314
# Epoch: 7		Loss/train: 0.00314	Loss/test: 0.00314
# Epoch: 8		Loss/train: 0.00308	Loss/test: 0.00305
# Epoch: 9		Loss/train: 0.00303	Loss/test: 0.00339
# Epoch: 10		Loss/train: 0.00298	Loss/test: 0.00304
# Epoch: 11		Loss/train: 0.00293	Loss/test: 0.00299
# Epoch: 12		Loss/train: 0.00291	Loss/test: 0.00296
# Epoch: 13		Loss/train: 0.00288	Loss/test: 0.00299
# Epoch: 14		Loss/train: 0.00285	Loss/test: 0.00300
# Epoch: 15		Loss/train: 0.00281	Loss/test: 0.00299
# Epoch: 16		Loss/train: 0.00283	Loss/test: 0.00296
# Epoch: 17		Loss/train: 0.00282	Loss/test: 0.00299
# Epoch: 18		Loss/train: 0.00274	Loss/test: 0.00297
# Epoch: 19		Loss/train: 0.00276	Loss/test: 0.00293
# Epoch: 20		Loss/train: 0.00270	Loss/test: 0.00290
# After training:		Loss/train: 0.00238	Loss/test: 0.00290
# ------------------------------------------------------------------
# 			Training model: 3
# ------------------------------------------------------------------
# Before training:	Loss/train: 0.00792	Loss/test: 0.00839
# Epoch: 1		Loss/train: 0.00586	Loss/test: 0.00463
# Epoch: 2		Loss/train: 0.00401	Loss/test: 0.00395
# Epoch: 3		Loss/train: 0.00363	Loss/test: 0.00366
# Epoch: 4		Loss/train: 0.00340	Loss/test: 0.00356
# Epoch: 5		Loss/train: 0.00329	Loss/test: 0.00358
# Epoch: 6		Loss/train: 0.00322	Loss/test: 0.00352
# Epoch: 7		Loss/train: 0.00316	Loss/test: 0.00335
# Epoch: 8		Loss/train: 0.00307	Loss/test: 0.00337
# Epoch: 9		Loss/train: 0.00302	Loss/test: 0.00322
# Epoch: 10		Loss/train: 0.00296	Loss/test: 0.00332
# Epoch: 11		Loss/train: 0.00294	Loss/test: 0.00336
# Epoch: 12		Loss/train: 0.00293	Loss/test: 0.00322
# Epoch: 13		Loss/train: 0.00285	Loss/test: 0.00314
# Epoch: 14		Loss/train: 0.00280	Loss/test: 0.00319
# Epoch: 15		Loss/train: 0.00280	Loss/test: 0.00312
# Epoch: 16		Loss/train: 0.00279	Loss/test: 0.00326
# Epoch: 17		Loss/train: 0.00270	Loss/test: 0.00312
# Epoch: 18		Loss/train: 0.00269	Loss/test: 0.00313
# Epoch: 19		Loss/train: 0.00264	Loss/test: 0.00310
# Epoch: 20		Loss/train: 0.00264	Loss/test: 0.00309
# After training:		Loss/train: 0.00238	Loss/test: 0.00309
# ------------------------------------------------------------------
# 			Training model: 4
# ------------------------------------------------------------------
# Before training:	Loss/train: 0.00791	Loss/test: 0.00791
# Epoch: 1		Loss/train: 0.00577	Loss/test: 0.00414
# Epoch: 2		Loss/train: 0.00393	Loss/test: 0.00384
# Epoch: 3		Loss/train: 0.00352	Loss/test: 0.00352
# Epoch: 4		Loss/train: 0.00338	Loss/test: 0.00340
# Epoch: 5		Loss/train: 0.00330	Loss/test: 0.00352
# Epoch: 6		Loss/train: 0.00318	Loss/test: 0.00327
# Epoch: 7		Loss/train: 0.00309	Loss/test: 0.00345
# Epoch: 8		Loss/train: 0.00307	Loss/test: 0.00318
# Epoch: 9		Loss/train: 0.00300	Loss/test: 0.00317
# Epoch: 10		Loss/train: 0.00294	Loss/test: 0.00314
# Epoch: 11		Loss/train: 0.00292	Loss/test: 0.00316
# Epoch: 12		Loss/train: 0.00287	Loss/test: 0.00312
# Epoch: 13		Loss/train: 0.00280	Loss/test: 0.00320
# Epoch: 14		Loss/train: 0.00281	Loss/test: 0.00314
# Epoch: 15		Loss/train: 0.00280	Loss/test: 0.00314
# Epoch: 16		Loss/train: 0.00280	Loss/test: 0.00312
# Epoch: 17		Loss/train: 0.00273	Loss/test: 0.00305
# Epoch: 18		Loss/train: 0.00265	Loss/test: 0.00308
# Epoch: 19		Loss/train: 0.00267	Loss/test: 0.00310
# Epoch: 20		Loss/train: 0.00263	Loss/test: 0.00308
# After training:		Loss/train: 0.00236	Loss/test: 0.00308
# ------------------------------------------------------------------
# 			Training model: 5
# ------------------------------------------------------------------
# Before training:	Loss/train: 0.00798	Loss/test: 0.00778
# Epoch: 1		Loss/train: 0.00578	Loss/test: 0.00393
# Epoch: 2		Loss/train: 0.00398	Loss/test: 0.00349
# Epoch: 3		Loss/train: 0.00363	Loss/test: 0.00335
# Epoch: 4		Loss/train: 0.00344	Loss/test: 0.00317
# Epoch: 5		Loss/train: 0.00329	Loss/test: 0.00321
# Epoch: 6		Loss/train: 0.00318	Loss/test: 0.00318
# Epoch: 7		Loss/train: 0.00315	Loss/test: 0.00304
# Epoch: 8		Loss/train: 0.00308	Loss/test: 0.00311
# Epoch: 9		Loss/train: 0.00305	Loss/test: 0.00299
# Epoch: 10		Loss/train: 0.00299	Loss/test: 0.00292
# Epoch: 11		Loss/train: 0.00294	Loss/test: 0.00293
# Epoch: 12		Loss/train: 0.00292	Loss/test: 0.00289
# Epoch: 13		Loss/train: 0.00288	Loss/test: 0.00298
# Epoch: 14		Loss/train: 0.00280	Loss/test: 0.00290
# Epoch: 15		Loss/train: 0.00281	Loss/test: 0.00287
# Epoch: 16		Loss/train: 0.00278	Loss/test: 0.00286
# Epoch: 17		Loss/train: 0.00278	Loss/test: 0.00304
# Epoch: 18		Loss/train: 0.00272	Loss/test: 0.00286
# Epoch: 19		Loss/train: 0.00271	Loss/test: 0.00285
# Epoch: 20		Loss/train: 0.00268	Loss/test: 0.00277
# After training:		Loss/train: 0.00236	Loss/test: 0.00277

# %% [markdown]
# ## Overall Results

# %%
def get_results_df(train_df, test_df, model_preds):

  # create new results df with model scaled preds
  preds_df = pd.DataFrame(model_preds)
  results_df = test_df.reset_index(drop=True)\
              .join(preds_df)\
              .rename(columns={0:'scaled_pred'})\
              .sort_values(by='essay_set')\
              .reset_index(drop=True)

  # move score to last colum
  s_df = results_df.pop('score')
  results_df['score'] = s_df

  # scale back to original range by essay set
  preds = pd.Series(dtype='float64')
  for essay_set in range(1,9):
    scaler = StandardScaler()  
    score_df = train_df[train_df['essay_set'] == essay_set]['score'].to_frame()
    scaler.fit(score_df)
    scaled_preds = results_df.loc[results_df['essay_set'] == essay_set, 'scaled_pred'].to_frame()
    preds_rescaled = scaler.inverse_transform(scaled_preds).round(0).astype('int')
    preds = preds.append(pd.Series(np.squeeze(np.asarray(preds_rescaled))), ignore_index=True)

  # append to results df
  results_df['pred'] = preds

  return results_df

# %%
# list of mqw_kappa for each model
mqwk_list = []

for model_id in test_df_dict:

  results_df = get_results_df(train_df_dict[model_id], test_df_dict[model_id], preds_dict[model_id])

  kappas_by_set = []
  for essay_set in range(1,9):
    kappas_by_set.append(kappa(results_df.loc[results_df['essay_set'] == essay_set, 'score'],
                            results_df.loc[results_df['essay_set'] == essay_set, 'pred'],
                            weights='quadratic'))
    
  mqwk_list.append(np.mean(kappas_by_set))
print('----------------------------------------------')
print('mean QWK after 5-fold cross-validation:\t{:.4f}'.format(np.mean(mqwk_list)))
print('Max mean QWK:\t\t\t\t{:.4f}'.format(max(mqwk_list)))
print('Min mean QWK:\t\t\t\t{:.4f}'.format(min(mqwk_list)))

raters_kappas = []
for essay_set in range(1,9):
  raters_kappas.append(kappa(dataset.loc[dataset['essay_set'] == essay_set, 'rater1'], 
                      dataset.loc[dataset['essay_set'] == essay_set, 'rater2'],
                      weights='quadratic'))
  
mqwk_raters = np.mean(raters_kappas)
print('----------------------------------------------')
print('mean QWK for two human raters:\t\t{:.4f}'.format(mqwk_raters))
print('----------------------------------------------')
# Out:
# ----------------------------------------------
# mean QWK after 5-fold cross-validation:	0.7396
# Max mean QWK:				0.7494
# Min mean QWK:				0.7342
# ----------------------------------------------
# mean QWK for two human raters:		0.7537
# ----------------------------------------------

# %% [markdown]
# ## Results by Model

# %%
def show_results(id):
  
  model_id = f"model_{id}"
  results_df = get_results_df(train_df_dict[model_id], test_df_dict[model_id], preds_dict[model_id])

  kappas_by_set = []
  for essay_set in range(1,9):
    kappas_by_set.append(kappa(results_df.loc[results_df['essay_set'] == essay_set, 'score'],
                            results_df.loc[results_df['essay_set'] == essay_set, 'pred'],
                            weights='quadratic'))
  print('--------------------------------------')
  print(f"\tResults for model: {id}")
  print('--------------------------------------')
  for essay_set in range(8):
    print('Kappa for essay set {:}:\t\t{:.4f}'.format(essay_set+1, kappas_by_set[essay_set]))
  print('mean QWK:\t\t\t{:.4f}'.format(np.mean(kappas_by_set)))
  
  return results_df

def plot_results(results_df, id):
  set_number = 0
  fig, ax = plt.subplots(4,2, figsize=(9,9), sharey=False)
  for i in range(4):
    for j in range(2):
      set_number += 1
      results_df[results_df['essay_set'] == set_number]\
        [['score', 'pred']]\
        .plot.hist(histtype='step', bins=20, ax=ax[i, j], rot=0)
      ax[i,j].set_title('Set %i' % set_number)
  ax[3,0].locator_params(nbins=10)
  ax[3,1].locator_params(nbins=10)
  plt.suptitle(f'Histograms of scores for Model {id}')
  plt.tight_layout(rect=[0, 0.03, 1, 0.95])
  plt.show()

# %% [markdown]
# ### Model 1

# %%
results_df = show_results(1)
# Out:
# --------------------------------------
# 	Results for model: 1
# --------------------------------------
# Kappa for essay set 1:		0.7794
# Kappa for essay set 2:		0.6542
# Kappa for essay set 3:		0.6420
# Kappa for essay set 4:		0.7813
# Kappa for essay set 5:		0.7789
# Kappa for essay set 6:		0.8065
# Kappa for essay set 7:		0.8066
# Kappa for essay set 8:		0.6902
# mean QWK:			0.7424

# %%
results_df.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 1      1267          1  In my opinion i think computers have a positiv...
# 2      1263          1  Dear @ORGANIZATION1, I think that more people ...
# 3      1260          1  Dear local newspaper, @CAPS1 name is @CAPS2 @C...
# 4      1259          1  To whomever this @MONTH1 concern, @CAPS1 your ...
#
#    rater1  rater2  scaled_score  scaled_pred  score  pred
# 0       4       3     -0.993622    -0.900549      7     7
# 1       4       4     -0.343483    -0.261130      8     8
# 2       5       4      0.306655    -0.432126      9     8
# 3       4       4     -0.343483    -0.329276      8     8
# 4       5       5      0.956794     0.858960     10    10

# %%
plot_results(results_df, 1)

# %% [markdown]
# ### Model 2

# %%
results_df = show_results(2)
# Out:
# --------------------------------------
# 	Results for model: 2
# --------------------------------------
# Kappa for essay set 1:		0.8039
# Kappa for essay set 2:		0.6903
# Kappa for essay set 3:		0.6891
# Kappa for essay set 4:		0.7781
# Kappa for essay set 5:		0.7804
# Kappa for essay set 6:		0.7734
# Kappa for essay set 7:		0.7930
# Kappa for essay set 8:		0.6871
# mean QWK:			0.7494

# %%
results_df.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         5          1  Dear @LOCATION1, I know having computers has a...
# 1      1162          1  Dear Local @CAPS1 Newspaper, @CAPS2 I see why ...
# 2      1154          1  Dear Readers, I understand that some @MONTH1 t...
# 3      1148          1  Dear @CAPS1, @CAPS2 you probably have seen the...
# 4      1147          1  Dear @ORGANIZATION1 staff, Are computers helpf...
#
#    rater1  rater2  scaled_score  scaled_pred  score  pred
# 0       4       4     -0.343483     0.321078      8     9
# 1       4       4     -0.343483     0.175269      8     9
# 2       4       4     -0.343483    -1.097512      8     7
# 3       5       4      0.306655     0.185041      9     9
# 4       4       5      0.306655     0.872792      9    10

# %%
plot_results(results_df, 2)

# %% [markdown]
# ### Model 3

# %%
results_df = show_results(3)
# Out:
# --------------------------------------
# 	Results for model: 3
# --------------------------------------
# Kappa for essay set 1:		0.7928
# Kappa for essay set 2:		0.6749
# Kappa for essay set 3:		0.6648
# Kappa for essay set 4:		0.8061
# Kappa for essay set 5:		0.7585
# Kappa for essay set 6:		0.7931
# Kappa for essay set 7:		0.7699
# Kappa for essay set 8:		0.6138
# mean QWK:			0.7343

# %%
results_df.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 1      1208          1  I disaree with computers are for you becau if ...
# 2      1204          1  To @CAPS1 @CAPS6 @MONTH1 concern: @CAPS2 I hav...
# 3      1200          1  Dear local newspaper, @CAPS1 it has been broug...
# 4      1199          1  Computers are helpful in everyone's life. New ...
#
#    rater1  rater2  scaled_score  scaled_pred  score  pred
# 0       5       4      0.306655     0.519810      9     9
# 1       3       4     -0.993622    -2.094605      7     5
# 2       4       5      0.306655     1.187636      9    10
# 3       5       4      0.306655     0.817470      9    10
# 4       4       4     -0.343483     0.197064      8     9

# %%
plot_results(results_df, 3)

# %% [markdown]
# ### Model 4

# %%
results_df = show_results(4)
# Out:
# --------------------------------------
# 	Results for model: 4
# --------------------------------------
# Kappa for essay set 1:		0.7999
# Kappa for essay set 2:		0.6635
# Kappa for essay set 3:		0.6585
# Kappa for essay set 4:		0.7872
# Kappa for essay set 5:		0.8066
# Kappa for essay set 6:		0.7704
# Kappa for essay set 7:		0.7951
# Kappa for essay set 8:		0.5926
# mean QWK:			0.7342

# %%
results_df.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         1          1  Dear local newspaper, I think effects computer...
# 1      1165          1  Dear @PERSON1 @CAPS1 I am writing this letter ...
# 2      1164          1  Dear @CAPS1, I am aware of the current debate ...
# 3      1163          1  Dear Newspaper, I strongly believe that the ef...
# 4      1158          1  Dear newspaper I think that there are many rea...
#
#    rater1  rater2  scaled_score  scaled_pred  score  pred
# 0       4       4     -0.343483     0.016073      8     9
# 1       4       4     -0.343483    -0.267532      8     8
# 2       4       5      0.306655     1.408654      9    11
# 3       5       5      0.956794     1.468701     10    11
# 4       4       5      0.306655     0.374843      9     9

# %%
plot_results(results_df, 4)

# %% [markdown]
# ### Model 5

# %%
results_df = show_results(5)
# Out:
# --------------------------------------
# 	Results for model: 5
# --------------------------------------
# Kappa for essay set 1:		0.8087
# Kappa for essay set 2:		0.6927
# Kappa for essay set 3:		0.6962
# Kappa for essay set 4:		0.7654
# Kappa for essay set 5:		0.7827
# Kappa for essay set 6:		0.7762
# Kappa for essay set 7:		0.8184
# Kappa for essay set 8:		0.5616
# mean QWK:			0.7378

# %%
results_df.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         6          1  Dear @LOCATION1, I think that computers have a...
# 1      1268          1  People use computers everyday. There's so many...
# 2      1265          1  Dear editors, I was planning on taking a trip ...
# 3      1261          1  Have you ever had someone move away and you wa...
# 4      1250          1  Dear The @CAPS1 newspaper, @CAPS2 in front of ...
#
#    rater1  rater2  scaled_score  scaled_pred  score  pred
# 0       4       4     -0.343483    -0.533359      8     8
# 1       4       4     -0.343483    -0.664476      8     7
# 2       5       5      0.956794     0.507694     10     9
# 3       4       5      0.306655     0.340489      9     9
# 4       6       6      2.257071     1.061068     12    10

# %%
plot_results(results_df, 5)
